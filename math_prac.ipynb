# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in c:\users\12146\anaconda3\lib\site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\12146\anaconda3\lib\site-packages (from sympy) (1.3.0)

# %%
from sympy import *

# %%
from sympy.plotting import plot3d

# %%
x, y = symbols('x y')

# %%
f = 2*x + 3*y

# %%
plot3d(f)

# %%
from sympy import *

# %%
x = symbols('x')

# %%
f = x**2 + 1

# %%
plot(f)

# %%
def f(x):
    return 2 * x + 1

# %%
x_values = [0,1,2,3]

# %%
for x in x_values:
    y = f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %%
from sympy import *

# %%
x = symbols('x')

# %%
f = 2*x + 1

# %%
plot(f)

# %%
summation = sum(2*i for i in range(1,6))

# %%
print(summation)
# Out:
# 30

# %%
x = [1 ,4, 6, 2]

# %%
n = len(x)

# %%
summation = sum(10*x[i] for i in range(0,n))
print(summation)
# Out:
# 130

# %% [raw]
# from sumpy import *

# %%
i,n = symbols('i n')

# %%
summation =Sum(2*i,(i,1,n))

# %%
up_to_5 = summation.subs(n, 5)
print(up_to_5.doit())
# Out:
# 30

# %%
x = log(8,2)

# %%
print(x)
# Out:
# 3

# %%
from sympy import *

# %%
n = symbols('n')

# %%
f = (1 +(1/n))**n

# %% [raw]
# result = limit(f, n, oo)

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 print(result)
#
# NameError: name 'result' is not defined

# %%
import math

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
math.sqrt(8)
# Out:
# 2.8284271247461903

# %%
omport sympy
# Out:
#   Cell In[101], line 1
#     omport sympy
#            ^
# SyntaxError: invalid syntax

# %%
import sympy

# %%
sympy.sqrt(3)
# Out:
# sqrt(3)

# %%
from sympy import *

# %%
x = symbols('x')

# %%
f = x**2

# %%
dx_f = diff(f)

# %%
print(dx_f)
# Out:
# 2*x

# %%
print(dx_f.subs(x,3))
# Out:
# 6

# %%
def f(x):
    return x**2

# %%
def dx_f(x):
    return 2*x

# %%
slop_At_2 = dx_f(2)

# %%
print(slop_At_2)
# Out:
# 4

# %%
print(dx_f.subs(x,2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 print(dx_f.subs(x,2))
#
# AttributeError: 'function' object has no attribute 'subs'

# %%
from sympy import *

# %%
from sympy.plotting import plot3d

# %%
x,y = symbols('x y')

# %%
f = 2*x**3 +3*y**3

# %%
dx_f = diff(f,x)

# %%
dy_f = diff(f,y)

# %%
print(dx_f)
# Out:
# 6*x**2

# %%
print(dy_f)
# Out:
# 9*y**2

# %%
plot3d(f)

# %%
from sympy import *

# %%
x = symbols('x')

# %%
f = x**2 + 1

# %%
area = integrate(f, (x, 0, 1))

# %%
print(area)
# Out:
# 4/3
